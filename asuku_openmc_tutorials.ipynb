# %% [markdown]
# <a href="https://colab.research.google.com/github/asukuabdulsamad/asuku-tutorials/blob/main/asuku_openmc_tutorials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_from_url("https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-Linux-x86_64.sh")
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
! conda install openmc=0.15.2=nodagmc_nompi_* -y -q
import openmc
print("Running OpenMC:", openmc.__version__)
# !wget -O /content/endfb71.tar.xz https://anl.box.com/shared/static/uhbxlrx7hvxqw27psymfbhi7bx7s6u6a.xz
# !tar -xf endfb71.tar.xz
import os
if (not os.path.isfile("/content/endfb-viii.0-hdf5/cross_sections.xml")):
  raise ValueError("Installation of cross sections was not completed!")
else:
  print("Installation completed")

# !cat "/content/endfb-viii.0-hdf5/cross_sections.xml" | head -10

os.environ['OPENMC_CROSS_SECTIONS'] = "/content/endfb-viii.0-hdf5/cross_sections.xml"
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openmc==0.15.2[build=nodagmc_nompi_*]
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asttokens-3.0.1            |     pyhd8ed1ab_0          28 KB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_3          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_3          19 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
# ...

# %% [markdown]
# In this tutorials we will learn how to model use openmc for reactor physics analysis. We want to model the Generic Miniature Neutron Source Reactor![output_0_2.png](data:image/png;base64,...)![output_0_1.png](data:image/png;base64,...)

# %%
import openmc
